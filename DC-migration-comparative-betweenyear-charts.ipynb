# %% [markdown]
# Going to try with matplot lib
#
# I used chatgpt to help me generate some of this initial code

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors
import plotly.express as px

# %% [markdown]
# Read in dataframes, and then make a list of dataframes so I can run through them all

# %%
#following election years
df_2005 = pd.read_csv('DC-migration-2005.csv')
df_2009 = pd.read_csv('DC-migration-2009.csv')
df_2013 = pd.read_csv('DC-migration-2013.csv')
df_2017 = pd.read_csv('DC-migration-2017.csv')
df_2021 = pd.read_csv('DC-migration-2021.csv')


#pre-election years for comparison

df_2006 = pd.read_csv('DC-migration-2006.csv')
df_2007 = pd.read_csv('DC-migration-2007.csv')
df_2008 = pd.read_csv('DC-migration-2008.csv')

df_2010 = pd.read_csv('DC-migration-2010.csv')
df_2011 = pd.read_csv('DC-migration-2011.csv')
df_2012 = pd.read_csv('DC-migration-2012.csv')

df_2014 = pd.read_csv('DC-migration-2013.csv')
df_2015 = pd.read_csv('DC-migration-2015.csv')
df_2016 = pd.read_csv('DC-migration-2016.csv')

df_2018 = pd.read_csv('DC-migration-2018.csv')
df_2019 = pd.read_csv('DC-migration-2019.csv')

# %% [markdown]
# Drop the initial columns that were carried over from the indexes and messing up this data.

# %%
df_2005 = df_2005.drop(columns=["Unnamed: 0"])
df_2006 = df_2006.drop(columns=["Unnamed: 0"])
df_2007 = df_2007.drop(columns=["Unnamed: 0"])
df_2008 = df_2008.drop(columns=["Unnamed: 0"])
df_2009 = df_2009.drop(columns=["Unnamed: 0"])
df_2010 = df_2010.drop(columns=["Unnamed: 0"])
df_2011 = df_2011.drop(columns=["Unnamed: 0"])
df_2012 = df_2012.drop(columns=["Unnamed: 0"])
df_2013 = df_2013.drop(columns=["Unnamed: 0"])
df_2014 = df_2014.drop(columns=["Unnamed: 0"])
df_2015 = df_2015.drop(columns=["Unnamed: 0"])
df_2016 = df_2016.drop(columns=["Unnamed: 0"])
df_2017 = df_2017.drop(columns=["Unnamed: 0"])
df_2018 = df_2018.drop(columns=["Unnamed: 0"])
df_2019 = df_2019.drop(columns=["Unnamed: 0"])
df_2021 = df_2021.drop(columns=["Unnamed: 0"])

# %%
df_2005.tail()

df_2015.tail()
# Out:
#             state  pop_migrated  MOE +/-  state_population  migrated_adjusted  \
# 43        Vermont           117      143            643077           0.000182
# 44     Washington           134      164           7705281           0.000017
# 45  West Virginia           478      432           1793716           0.000266
# 46      Wisconsin           514      421           5893718           0.000087
# 47        Wyoming             0      200            576851           0.000000
#
#     moe_adjusted winning_party  winner_percent_of_votes
# 43      0.000222      DEMOCRAT                 0.665706
# 44      0.000021      DEMOCRAT                 0.561634
# 45      0.000241    REPUBLICAN                 0.622958
# 46      0.000071      DEMOCRAT                 0.527762
# 47      0.000347    REPUBLICAN                 0.681936

# %% [markdown]
# Add in a state year column so in order to be able to loop through the dataframes

# %%
df_2005['year'] = 2005
df_2006['year'] = 2006
df_2007['year'] = 2007
df_2008['year'] = 2008
df_2009['year'] = 2009
df_2010['year'] = 2010
df_2011['year'] = 2011
df_2012['year'] = 2012
df_2013['year'] = 2013
df_2014['year'] = 2014
df_2015['year'] = 2015
df_2016['year'] = 2016
df_2017['year'] = 2017
df_2018['year'] = 2018
df_2019['year'] = 2019
df_2021['year'] = 2021

# %% [markdown]
# Forming a new dataframe to compare other years with 2017. Starting with 2015, 2016, 2017 data

# %%
df_17_compare = pd.DataFrame()

df_17_compare['state'] = df_2017['state'].copy()
df_17_compare['pop_migrated_2015'] = df_2015['pop_migrated'].copy()
df_17_compare['pop_migrated_2016'] = df_2016['pop_migrated'].copy()
df_17_compare['pop_migrated_2017'] = df_2017['pop_migrated'].copy()

# %% [markdown]
# Make a new column averaging the non election years -- i.e. 2015 and 2016 (since census is early in year before election)

# %%
df_17_compare['15_16_avg'] = (df_17_compare['pop_migrated_2015'] + df_17_compare['pop_migrated_2016']) / 2

# %%
df_17_compare.head(30)
# Out:
#             state  pop_migrated_2015  pop_migrated_2016  pop_migrated_2017  \
# 0         Alabama                359                140                494
# 1          Alaska                235                 77                  0
# 2         Arizona                367                744                549
# 3        Arkansas                203                  0                105
# 4      California               4119               3908               3763
# 5        Colorado                433                531               1109
# 6     Connecticut               1292               1225               1149
# 7        Delaware                252                278                375
# 8         Florida               2731               2717               1182
# 9         Georgia               1013               1105               1507
# 10         Hawaii                 52                103                 29
# ...

# %% [markdown]
# Make a new column with the percent change between 2016 and 2017 years

# %%
df_17_compare['pct_change_pre_post_election'] = (
    df_17_compare['pop_migrated_2017'] - df_17_compare['15_16_avg']
) / df_17_compare["15_16_avg"] * 100

df_17_compare.head()
# Out:
#         state  pop_migrated_2015  pop_migrated_2016  pop_migrated_2017  \
# 0     Alabama                359                140                494
# 1      Alaska                235                 77                  0
# 2     Arizona                367                744                549
# 3    Arkansas                203                  0                105
# 4  California               4119               3908               3763
#
#    15_16_avg  pct_change_pre_post_election
# 0      249.5                     97.995992
# 1      156.0                   -100.000000
# 2      555.5                     -1.170117
# 3      101.5                      3.448276
# 4     4013.5                     -6.241435

# %% [markdown]
# Add back in the party info

# %%
df_17_compare['winning_party'] = df_2017['winning_party'] 
df_17_compare['winner_percent_of_votes'] = df_2017['winner_percent_of_votes'] 

df_17_compare.head()
# Out:
#         state  pop_migrated_2015  pop_migrated_2016  pop_migrated_2017  \
# 0     Alabama                359                140                494
# 1      Alaska                235                 77                  0
# 2     Arizona                367                744                549
# 3    Arkansas                203                  0                105
# 4  California               4119               3908               3763
#
#    15_16_avg  pct_change_pre_post_election winning_party  \
# 0      249.5                     97.995992    REPUBLICAN
# 1      156.0                   -100.000000    REPUBLICAN
# 2      555.5                     -1.170117    REPUBLICAN
# 3      101.5                      3.448276    REPUBLICAN
# 4     4013.5                     -6.241435      DEMOCRAT
#
#    winner_percent_of_votes
# 0                 0.620831
# 1                 0.512815
# 2                 0.486716
# 3                 0.605741
# 4                 0.617264

# %% [markdown]
# Add a total column, so that I can see tota numbers migrating into D.C. in an election year and not in an election year.

# %%
df_17_compare.loc["Total"] = df_17_compare.sum(numeric_only=True)

df_17_compare.head()
# Out:
#         state  pop_migrated_2015  pop_migrated_2016  pop_migrated_2017  \
# 0     Alabama              359.0              140.0              494.0
# 1      Alaska              235.0               77.0                0.0
# 2     Arizona              367.0              744.0              549.0
# 3    Arkansas              203.0                0.0              105.0
# 4  California             4119.0             3908.0             3763.0
#
#    15_16_avg  pct_change_pre_post_election winning_party  \
# 0      249.5                     97.995992    REPUBLICAN
# 1      156.0                   -100.000000    REPUBLICAN
# 2      555.5                     -1.170117    REPUBLICAN
# 3      101.5                      3.448276    REPUBLICAN
# 4     4013.5                     -6.241435      DEMOCRAT
#
#    winner_percent_of_votes
# 0                 0.620831
# 1                 0.512815
# 2                 0.486716
# 3                 0.605741
# 4                 0.617264

# %%
df_17_compare.sort_values('pct_change_pre_post_election', ascending=False)
# Out:
#                 state  pop_migrated_2015  pop_migrated_2016  \
# Total             NaN            37151.0            35529.0
# 11              Idaho                5.0                0.0
# 29         New Mexico               40.0                1.0
# 43            Vermont              117.0                0.0
# 5            Colorado              433.0              531.0
# 0             Alabama              359.0              140.0
# 42               Utah              177.0              249.0
# 12           Illinois              785.0             2418.0
# 41              Texas             1314.0             2213.0
# 40          Tennessee              873.0              452.0
# 28         New Jersey             1804.0             1494.0
# 17          Louisiana              392.0              197.0
# 9             Georgia             1013.0             1105.0
# 7            Delaware              252.0              278.0
# 23           Missouri              141.0              566.0
# ...

# %% [markdown]
# Forming a new dataframe to compare things with 2021. Will start with 2018 and 2019, and 2021 data (there is no 2018 instead of 2020 because no data in 2020 because of covid)

# %%
df_21_compare = pd.DataFrame()

df_21_compare['state'] = df_2019['state'].copy()
df_21_compare['pop_migrated_2018'] = df_2018['pop_migrated'].copy()
df_21_compare['pop_migrated_2019'] = df_2019['pop_migrated'].copy()
df_21_compare['pop_migrated_2021'] = df_2021['pop_migrated'].copy()

# %% [markdown]
# Make a column averaging 2018 and 2019

# %%
df_21_compare['18-19_avg'] = (df_21_compare['pop_migrated_2018'] + df_21_compare['pop_migrated_2019']) / 2

# %% [markdown]
# Add back in the party info

# %%
df_21_compare['winning_party'] = df_2021['winning_party'] 
df_21_compare['winner_percent_of_votes'] = df_2021['winner_percent_of_votes'] 

df_21_compare.head()
# Out:
#         state  pop_migrated_2018  pop_migrated_2019  pop_migrated_2021  \
# 0     Alabama                174                462                342
# 1      Alaska                  0                338                196
# 2     Arizona                204                291                674
# 3    Arkansas                  0                  0                 37
# 4  California               3803               3437               3945
#
#    18-19_avg winning_party  winner_percent_of_votes
# 0      318.0    REPUBLICAN                 0.620316
# 1      169.0    REPUBLICAN                 0.528331
# 2      247.5      DEMOCRAT                 0.493647
# 3        0.0    REPUBLICAN                 0.623957
# 4     3620.0      DEMOCRAT                 0.634839

# %% [markdown]
# Percent change 2019 vs 2021 of migrants to DC from each state

# %%
df_21_compare['pct_change_pre_post_election'] = (
    df_21_compare['pop_migrated_2021'] - df_21_compare['18-19_avg']
) / df_21_compare["18-19_avg"] * 100

df_21_compare.head()
# Out:
#         state  pop_migrated_2018  pop_migrated_2019  pop_migrated_2021  \
# 0     Alabama                174                462                342
# 1      Alaska                  0                338                196
# 2     Arizona                204                291                674
# 3    Arkansas                  0                  0                 37
# 4  California               3803               3437               3945
#
#    18-19_avg winning_party  winner_percent_of_votes  \
# 0      318.0    REPUBLICAN                 0.620316
# 1      169.0    REPUBLICAN                 0.528331
# 2      247.5      DEMOCRAT                 0.493647
# 3        0.0    REPUBLICAN                 0.623957
# 4     3620.0      DEMOCRAT                 0.634839
#
#    pct_change_pre_post_election
# 0                      7.547170
# 1                     15.976331
# 2                    172.323232
# 3                           inf
# 4                      8.977901

# %% [markdown]
# Add in a total column so that I can see tota numbers migrating into D.C. in an election year and not in an election year.

# %%
df_21_compare.loc["Total"] = df_21_compare.sum(numeric_only=True)

df_21_compare.head()
# Out:
#         state  pop_migrated_2018  pop_migrated_2019  pop_migrated_2021  \
# 0     Alabama              174.0              462.0              342.0
# 1      Alaska                0.0              338.0              196.0
# 2     Arizona              204.0              291.0              674.0
# 3    Arkansas                0.0                0.0               37.0
# 4  California             3803.0             3437.0             3945.0
#
#    18-19_avg winning_party  winner_percent_of_votes  \
# 0      318.0    REPUBLICAN                 0.620316
# 1      169.0    REPUBLICAN                 0.528331
# 2      247.5      DEMOCRAT                 0.493647
# 3        0.0    REPUBLICAN                 0.623957
# 4     3620.0      DEMOCRAT                 0.634839
#
#    pct_change_pre_post_election
# 0                      7.547170
# 1                     15.976331
# 2                    172.323232
# 3                           inf
# 4                      8.977901

# %%
df_21_compare.sort_values('pct_change_pre_post_election', ascending=False)
# Out:
#                 state  pop_migrated_2018  pop_migrated_2019  \
# Total             NaN            27047.0            34552.0
# 3            Arkansas                0.0                0.0
# 7            Delaware              182.0                0.0
# 15             Kansas                0.0               41.0
# 26             Nevada               36.0                0.0
# 11              Idaho                0.0               28.0
# 34           Oklahoma                0.0              185.0
# 18              Maine               61.0              448.0
# 21          Minnesota              143.0              278.0
# 35             Oregon               80.0              172.0
# 37       Rhode Island               87.0              138.0
# 27      New Hampshire              130.0               49.0
# 44         Washington              387.0              852.0
# 2             Arizona              204.0              291.0
# 45      West Virginia              294.0              324.0
# ...

# %%
df_21_compare.head()
# Out:
#         state  pop_migrated_2018  pop_migrated_2019  pop_migrated_2021  \
# 0     Alabama              174.0              462.0              342.0
# 1      Alaska                0.0              338.0              196.0
# 2     Arizona              204.0              291.0              674.0
# 3    Arkansas                0.0                0.0               37.0
# 4  California             3803.0             3437.0             3945.0
#
#    18-19_avg winning_party  winner_percent_of_votes  \
# 0      318.0    REPUBLICAN                 0.620316
# 1      169.0    REPUBLICAN                 0.528331
# 2      247.5      DEMOCRAT                 0.493647
# 3        0.0    REPUBLICAN                 0.623957
# 4     3620.0      DEMOCRAT                 0.634839
#
#    pct_change_pre_post_election
# 0                      7.547170
# 1                     15.976331
# 2                    172.323232
# 3                           inf
# 4                      8.977901

# %% [markdown]
# Now going to make a dataframe to compare other years with 2009

# %%
df_09_compare = pd.DataFrame()

#creating column with state name

df_09_compare['state'] = df_2009['state'].copy()

#column with the 2009 migration numbers

df_09_compare['pop_migrated_2021'] = df_2009['pop_migrated'].copy()

# %% [markdown]
# copying over the election information

# %%
df_09_compare['winning_party'] = df_2009['winning_party'] 

df_09_compare['winner_percent_of_votes'] = df_2009['winner_percent_of_votes'] 

df_09_compare.head()
# Out:
#         state  pop_migrated_2021 winning_party  winner_percent_of_votes
# 0     Alabama                203    REPUBLICAN                 0.603169
# 1      Alaska                240    REPUBLICAN                 0.594245
# 2     Arizona                 32    REPUBLICAN                 0.536352
# 3    Arkansas                106    REPUBLICAN                 0.587159
# 4  California               2980      DEMOCRAT                 0.610126

# %% [markdown]
# New method to see anomolies.
#
# Going to compare each year (all the states) to the average of all other years.

# %% [markdown]
# 2017

# %%
#average people from each state to DC in all years except 2017 

df_17_compare['avg_all years'] = (df_2005['pop_migrated'] + df_2006['pop_migrated'] + df_2007['pop_migrated'] + df_2008['pop_migrated'] + df_2009['pop_migrated'] + df_2010['pop_migrated'] + df_2011['pop_migrated'] + df_2012['pop_migrated'] + df_2013['pop_migrated'] + df_2014['pop_migrated'] + df_2015['pop_migrated'] + df_2016['pop_migrated'] + df_2018['pop_migrated'] + df_2019['pop_migrated'] + df_2021['pop_migrated']) / 15

#compare to 2017
df_17_compare['anomaly'] = df_17_compare['pop_migrated_2017'] / df_17_compare['avg_all years']

# %% [markdown]
# 2021

# %%
#average people from each state to DC in all years except 2021

df_21_compare['avg_all years'] = (df_2005['pop_migrated'] + df_2006['pop_migrated'] + df_2007['pop_migrated'] + df_2008['pop_migrated'] + df_2009['pop_migrated'] + df_2010['pop_migrated'] + df_2011['pop_migrated'] + df_2012['pop_migrated'] + df_2013['pop_migrated'] + df_2014['pop_migrated'] + df_2015['pop_migrated'] + df_2016['pop_migrated'] + df_2017['pop_migrated'] + df_2018['pop_migrated'] + df_2019['pop_migrated']) / 15

#compare to 2021

df_21_compare['anomaly'] = df_21_compare['pop_migrated_2021'] / df_21_compare['avg_all years']

# %% [markdown]
# 2009

# %%
#average people from each state to DC in all years except 2009

df_09_compare['avg_all years'] = (df_2005['pop_migrated'] + df_2006['pop_migrated'] + df_2007['pop_migrated'] + df_2008['pop_migrated'] + df_2010['pop_migrated'] + df_2011['pop_migrated'] + df_2012['pop_migrated'] + df_2013['pop_migrated'] + df_2014['pop_migrated'] + df_2015['pop_migrated'] + df_2016['pop_migrated'] + df_2017['pop_migrated'] + df_2018['pop_migrated'] + df_2019['pop_migrated'] + df_2021['pop_migrated']) / 15

#compare to 2009

df_09_compare['anomaly'] = df_09_compare['pop_migrated_2021'] / df_09_compare['avg_all years']

# %% [markdown]
# Look at anomalies

# %%
df_09_compare.sort_values('anomaly', ascending=False)
# Out:
#              state  pop_migrated_2021 winning_party  winner_percent_of_votes  \
# 47         Wyoming                 54    REPUBLICAN                 0.647138
# 18           Maine                390      DEMOCRAT                 0.577057
# 24         Montana                 66    REPUBLICAN                 0.495325
# 26          Nevada                147      DEMOCRAT                 0.551467
# 8          Florida               2275      DEMOCRAT                 0.510333
# 35          Oregon                285      DEMOCRAT                 0.567488
# 43         Vermont                161      DEMOCRAT                 0.674557
# 3         Arkansas                106    REPUBLICAN                 0.587159
# 46       Wisconsin                344      DEMOCRAT                 0.562178
# 39    South Dakota                 58    REPUBLICAN                 0.531590
# 5         Colorado                505      DEMOCRAT                 0.536602
# ...

# %%
df_17_compare.sort_values('anomaly', ascending=False)
# Out:
#                 state  pop_migrated_2015  pop_migrated_2016  \
# 11              Idaho                5.0                0.0
# 43            Vermont              117.0                0.0
# 42               Utah              177.0              249.0
# 5            Colorado              433.0              531.0
# 40          Tennessee              873.0              452.0
# 0             Alabama              359.0              140.0
# 12           Illinois              785.0             2418.0
# 41              Texas             1314.0             2213.0
# 13            Indiana              748.0              957.0
# 16           Kentucky              275.0              233.0
# 23           Missouri              141.0              566.0
# 21          Minnesota              545.0              542.0
# 28         New Jersey             1804.0             1494.0
# 17          Louisiana              392.0              197.0
# 29         New Mexico               40.0                1.0
# ...

# %% [markdown]
# Export

# %%
df_17_compare.to_csv('df_17_compare.csv')
df_21_compare.to_csv('df_21_compare.csv')
df_09_compare.to_csv('df_09_compare.csv')

# %% [markdown]
# Build condensed versions of just the anomolies for datawrapper charts -- all I want is the anomaly for 2009, for 2017, and for 2021 with the state names as irst column

# %%
df_anomaly_compare_2017 = pd.DataFrame()
df_anomaly_compare_2021 = pd.DataFrame()
df_anomaly_compare_2009 = pd.DataFrame()


df_anomaly_compare_2017['state'] = df_17_compare['state']
df_anomaly_compare_2017['2017_anomaly'] = df_17_compare['anomaly']
df_anomaly_compare_2017['winning_party'] = df_17_compare['winning_party']

df_anomaly_compare_2021['state'] = df_21_compare['state']
df_anomaly_compare_2021['2021_anomaly'] = df_21_compare['anomaly']
df_anomaly_compare_2021['winning_party'] = df_21_compare['winning_party']

df_anomaly_compare_2009['state'] = df_09_compare['state']
df_anomaly_compare_2009['2009_anomaly'] = df_09_compare['anomaly']
df_anomaly_compare_2009['winning_party'] = df_09_compare['winning_party']

# %%
df_anomaly_compare_2017.sort_values('2017_anomaly', ascending=False).head(15)
# Out:
#          state  2017_anomaly winning_party
# 11       Idaho      4.868952    REPUBLICAN
# 43     Vermont      4.051360      DEMOCRAT
# 42        Utah      2.640990    REPUBLICAN
# 5     Colorado      2.502256      DEMOCRAT
# 40   Tennessee      2.251171    REPUBLICAN
# 0      Alabama      2.231928    REPUBLICAN
# 12    Illinois      2.212662      DEMOCRAT
# 41       Texas      2.105289    REPUBLICAN
# 13     Indiana      2.026641    REPUBLICAN
# 16    Kentucky      1.759259    REPUBLICAN
# 23    Missouri      1.653264    REPUBLICAN
# 21   Minnesota      1.615613      DEMOCRAT
# 28  New Jersey      1.565838      DEMOCRAT
# 17   Louisiana      1.540432    REPUBLICAN
# 29  New Mexico      1.502188      DEMOCRAT

# %%
df_anomaly_compare_2017.sort_values('2017_anomaly', ascending=False).head(15)
# Out:
#          state  2017_anomaly winning_party
# 11       Idaho      4.868952    REPUBLICAN
# 43     Vermont      4.051360      DEMOCRAT
# 42        Utah      2.640990    REPUBLICAN
# 5     Colorado      2.502256      DEMOCRAT
# 40   Tennessee      2.251171    REPUBLICAN
# 0      Alabama      2.231928    REPUBLICAN
# 12    Illinois      2.212662      DEMOCRAT
# 41       Texas      2.105289    REPUBLICAN
# 13     Indiana      2.026641    REPUBLICAN
# 16    Kentucky      1.759259    REPUBLICAN
# 23    Missouri      1.653264    REPUBLICAN
# 21   Minnesota      1.615613      DEMOCRAT
# 28  New Jersey      1.565838      DEMOCRAT
# 17   Louisiana      1.540432    REPUBLICAN
# 29  New Mexico      1.502188      DEMOCRAT

# %% [markdown]
# Only save top 15

# %%
df_anomaly_compare_2017 = df_anomaly_compare_2017.sort_values('2017_anomaly', ascending=False).head(15) # all rows over 1.5x the avg
df_anomaly_compare_2021 = df_anomaly_compare_2021.sort_values('2021_anomaly', ascending=False).head(15) # all rows over 1.5x the avg
df_anomaly_compare_2009 = df_anomaly_compare_2009.sort_values('2009_anomaly', ascending=False).head(9) # all rows over 1.1x the avg

df_anomaly_compare_2009
# Out:
#         state  2009_anomaly winning_party
# 47    Wyoming      2.347826    REPUBLICAN
# 18      Maine      2.211720      DEMOCRAT
# 24    Montana      1.922330    REPUBLICAN
# 26     Nevada      1.573876      DEMOCRAT
# 8     Florida      1.358425      DEMOCRAT
# 35     Oregon      1.281475      DEMOCRAT
# 43    Vermont      1.244204      DEMOCRAT
# 3    Arkansas      1.136526    REPUBLICAN
# 46  Wisconsin      1.104925      DEMOCRAT

# %% [markdown]
# And export

# %%
df_anomaly_compare_2017.to_csv('df_anomaly_compare_2017.csv')
df_anomaly_compare_2021.to_csv('df_anomaly_compare_2021.csv')
df_anomaly_compare_2009.to_csv('df_anomaly_compare_2009.csv')

# %% [markdown]
# Make some maps of the anomolies for 2017 and 2021

# %%
import numpy as np
import matplotlib.colors as mcolors

# %% [markdown]
# cleaning for mapping

# %%
df_2017_formap = df_17_compare.sort_values('anomaly', ascending=False).head(10) # all rows over 1.5x the avg
df_2021_formap = df_21_compare.sort_values('anomaly', ascending=False).head(10) # all rows over 1.5x the avg
df_2009_formap = df_09_compare.sort_values('anomaly', ascending=False).head(10) # all rows over 1.1x the avg

# %%
us_state_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC"
}

for i in range(len(df_2017_formap)):
    df_2017_formap["state_code"] = df_2017_formap["state"].map(us_state_abbrev)
for i in range(len(df_2021_formap)):
    df_2021_formap["state_code"] = df_2021_formap["state"].map(us_state_abbrev)
for i in range(len(df_2009_formap)):
    df_2009_formap["state_code"] = df_2009_formap["state"].map(us_state_abbrev)

# %% [markdown]
# Making new column for shading on map

# %%
for i in range(len(df_2017_formap)):
    df_2017_formap["percent_won_and_party"] = np.where(
        df_2017_formap["winning_party"] == "DEMOCRAT",
        df_2017_formap["winner_percent_of_votes"],    # keep as-is (positive)
        df_2017_formap["winner_percent_of_votes"] * -1    # flip sign to negative
    )

for i in range(len(df_2021_formap)):
    df_2021_formap["percent_won_and_party"] = np.where(
        df_2021_formap["winning_party"] == "DEMOCRAT",
        df_2021_formap["winner_percent_of_votes"],    # keep as-is (positive)
        df_2021_formap["winner_percent_of_votes"] * -1   # flip sign to negative
    )

for i in range(len(df_2009_formap)):
    df_2009_formap["percent_won_and_party"] = np.where(
        df_2009_formap["winning_party"] == "DEMOCRAT",
        df_2009_formap["winner_percent_of_votes"],    # keep as-is (positive)
        df_2009_formap["winner_percent_of_votes"] * -1   # flip sign to negative
    )

# %%
df_2021_formap.head(5)

df_2017_formap.head(5)

df_2009_formap.head(5)

# %%
fig_2021_anomaly = px.choropleth(
    df_2021_formap,
    locations="state_code",
    locationmode="USA-states",
    color="percent_won_and_party",
    scope="usa",
    color_continuous_scale=["#AA0000", '#C88FE4',"#0645B4"],
    range_color=[-0.8, 0.8]
)

fig_2021_anomaly.show()

# %%
fig_2017_anomaly = px.choropleth(
    df_2017_formap,
    locations="state_code",
    locationmode="USA-states",
    color="percent_won_and_party",
    scope="usa",
    color_continuous_scale=["#AA0000", '#C88FE4',"#0645B4"],
    range_color=[-0.8, 0.8]
)

fig_2017_anomaly.show()

# %%
fig_2009_anomaly = px.choropleth(
    df_2009_formap,
    locations="state_code",
    locationmode="USA-states",
    color="percent_won_and_party",
    scope="usa",
    color_continuous_scale=["#AA0000", '#C88FE4',"#0645B4"],
    range_color=[-0.8, 0.8]
)

fig_2009_anomaly.show()

# %% [markdown]
# Save new maps

# %%
fig_2017_anomaly.write_image("2017_anomaly_map.svg", engine="kaleido")
fig_2021_anomaly.write_image("2021_anomaly_map.svg", engine="kaleido")

# %%
fig_2009_anomaly.write_image("2009_anomaly_map.svg", engine="kaleido")

# %% [markdown]
# Save new anomaly lists
