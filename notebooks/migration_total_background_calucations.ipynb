# %%
import pandas as pd

import numpy as np

# %% [markdown]
# read in .csv

# %%
df_2021 = pd.read_csv('DC-migration-2021.csv')

# %% [markdown]
# I want to find some overall migration numbers for the narrative part of my story.

# %% [markdown]
# First, in 2021 as a sample year, total migration to DC:
#
# Can see from original unparced data that total migration to DC is 57,746 +/- 5,874 in 2021.

# %% [markdown]
# Now I want to see how that figure compares to other states, adjusted per capita.
#
# I want to take that original excel file and pull out the total migration from each state and compare to population.
#
# Repeating parsing from the DC-migration-2021-ran.ipynb notebook

# %%
df = pd.read_excel('ORIGINAL DATA State_to_State_Migrations_Table_2021.xls')

df = df.iloc[np.r_[4:43, 44:77]] #drop top and bottom outside of actual chart in the excel file

df = df.dropna(how="all") #drop all rows with all na values

# %% [markdown]
# Rename columns

# %%
#for the first column

df.rename(columns={'Table with row headers in column A, L, W, AH, AS, BD, BO, BZ, CK, CV, and DG, and column headers in rows 6 through 8 and 45 through 47.': '0'}, inplace=True)

#for the rest of the columns:

for col in df.columns[1:130]:  # 2–129 (0-based index, so skip first col)
    if str(col).startswith("Unnamed:"):
        df.rename(columns={col: str(col).replace("Unnamed: ", "")}, inplace=True)

df.head()
# Out:
#                        0                           1      2  \
# 4   Current residence in  Population 1 year and over    NaN
# 5                    NaN                         NaN    NaN
# 6                    NaN                    Estimate    MOE
# 8         United States2                   328464538  34090
# 10               Alabama                     4989797   4341
#
#                         3       4                                   5       6  \
# 4   Same house 1 year ago     NaN  Same state of residence 1 year ago     NaN
# 5                     NaN     NaN                                 NaN     NaN
# 6                Estimate     MOE                            Estimate     MOE
# 8               286552923  190336                            32577121  167671
# 10                4392571   25089                              468964   23356
#
#                                           7      8         9  ...   120  \
# 4   Different state of residence 1 year ago    NaN       NaN  ...   NaN
# 5                                     Total    NaN   Alabama  ...   NaN
# 6                                  Estimate    MOE  Estimate  ...   MOE
# 8                                   7859837  75123    104481  ...  6515
# 10                                   115641  10300       NaN  ...   216
#
#                      121                122    123          124   125  \
# 4   Current residence in  Abroad 1 year ago    NaN          NaN   NaN
# 5                    NaN              Total    NaN  Puerto Rico   NaN
# 6                    NaN           Estimate    MOE     Estimate   MOE
# 8         United States2            1474657  34636        54669  7470
# 10               Alabama              12621   2388          534   436
#
#                  126   127              128    129
# 4                NaN   NaN              NaN    NaN
# 5   U.S. Island Area   NaN  Foreign Country    NaN
# 6           Estimate   MOE         Estimate    MOE
# 8              19587  4066          1400401  33711
# 10                29    47            12058   2400
#
# [5 rows x 130 columns]

# %% [markdown]
# Drop the whole end of the dataframe, as I wont be needing for this

# %%
df = df.loc[:, :'8']

# %% [markdown]
# Preserve NA values as 0s

# %%
df.iloc[3:] = df.iloc[3:].fillna('0')

df.head()
# Out:
#                        0                           1      2  \
# 4   Current residence in  Population 1 year and over    NaN
# 5                    NaN                         NaN    NaN
# 6                    NaN                    Estimate    MOE
# 8         United States2                   328464538  34090
# 10               Alabama                     4989797   4341
#
#                         3       4                                   5       6  \
# 4   Same house 1 year ago     NaN  Same state of residence 1 year ago     NaN
# 5                     NaN     NaN                                 NaN     NaN
# 6                Estimate     MOE                            Estimate     MOE
# 8               286552923  190336                            32577121  167671
# 10                4392571   25089                              468964   23356
#
#                                           7      8
# 4   Different state of residence 1 year ago    NaN
# 5                                     Total    NaN
# 6                                  Estimate    MOE
# 8                                   7859837  75123
# 10                                   115641  10300

# %% [markdown]
# Rename columns and drop columns I don't need.
# I want to keep only three columns: statename, Population 1 year and over, and Different state of residence 1 year ago -- total.
# I can calucate the rest from there.

# %%
#first, dealing with columns B-G/1-6)

column_0_name = 'state'

column_1_name = 'population 1 year and over (estimate)'
column_2_name = 'population 1 year and over (moe)'

column_5_name = 'Same state of residence 1 year ago (estimate)'
column_6_name = 'Same state of residence 1 year ago (moe)'

column_7_name = 'Different state of residence 1 year ago (estimate)'
column_8_name = 'Different state of residence 1 year ago (moe)'

df_clean = df.rename(columns ={
    '0': column_0_name,
    '1': column_1_name,
    '2': column_2_name,
    '5': column_5_name,
    '6': column_6_name,
    '7': column_7_name,
    '8': column_8_name})

df = df_clean

df.head()
# Out:
#                    state population 1 year and over (estimate)  \
# 4   Current residence in            Population 1 year and over
# 5                    NaN                                   NaN
# 6                    NaN                              Estimate
# 8         United States2                             328464538
# 10               Alabama                               4989797
#
#    population 1 year and over (moe)                      3       4  \
# 4                               NaN  Same house 1 year ago     NaN
# 5                               NaN                    NaN     NaN
# 6                               MOE               Estimate     MOE
# 8                             34090              286552923  190336
# 10                             4341                4392571   25089
#
#    Same state of residence 1 year ago (estimate)  \
# 4             Same state of residence 1 year ago
# 5                                            NaN
# 6                                       Estimate
# 8                                       32577121
# 10                                        468964
#
#    Same state of residence 1 year ago (moe)  \
# 4                                       NaN
# 5                                       NaN
# 6                                       MOE
# 8                                    167671
# 10                                    23356
#
#    Different state of residence 1 year ago (estimate)  \
# 4             Different state of residence 1 year ago
# 5                                               Total
# 6                                            Estimate
# 8                                             7859837
# 10                                             115641
#
#    Different state of residence 1 year ago (moe)
# 4                                            NaN
# 5                                            NaN
# 6                                            MOE
# 8                                          75123
# 10                                         10300

# %%
#drop columns I dont need (same house as 1 year ago estimate and MOE columns)
df.drop(['3', '4'], axis=1, inplace=True)

# %% [markdown]
# Delete subtitle rows

# %%
df = df.iloc[3:]

df.head()
# Out:
#              state population 1 year and over (estimate)  \
# 8   United States2                             328464538
# 10         Alabama                               4989797
# 11          Alaska                                723949
# 12         Arizona                               7202745
# 13        Arkansas                               2990311
#
#    population 1 year and over (moe)  \
# 8                             34090
# 10                             4341
# 11                             1517
# 12                             5156
# 13                             2937
#
#    Same state of residence 1 year ago (estimate)  \
# 8                                       32577121
# 10                                        468964
# 11                                         63611
# 12                                        759450
# 13                                        312848
#
#    Same state of residence 1 year ago (moe)  \
# 8                                    167671
# 10                                    23356
# 11                                     6501
# 12                                    24263
# 13                                    15129
#
#    Different state of residence 1 year ago (estimate)  \
# 8                                             7859837
# 10                                             115641
# 11                                              31378
# 12                                             264948
# 13                                              76108
#
#    Different state of residence 1 year ago (moe)
# 8                                          75123
# 10                                         10300
# 11                                          3888
# 12                                         14419
# 13                                          8024

# %%
df['Different state of residence 1 year ago (estimate)'] = pd.to_numeric(df['Different state of residence 1 year ago (estimate)'], errors='coerce')

df['population 1 year and over (estimate)'] = pd.to_numeric(df['population 1 year and over (estimate)'], errors='coerce')

df['new_people_adj'] = df['Different state of residence 1 year ago (estimate)'] / df['population 1 year and over (estimate)']

df.head()
# Out:
#              state  population 1 year and over (estimate)  \
# 8   United States2                            328464538.0
# 10         Alabama                              4989797.0
# 11          Alaska                               723949.0
# 12         Arizona                              7202745.0
# 13        Arkansas                              2990311.0
#
#    population 1 year and over (moe)  \
# 8                             34090
# 10                             4341
# 11                             1517
# 12                             5156
# 13                             2937
#
#    Same state of residence 1 year ago (estimate)  \
# 8                                       32577121
# 10                                        468964
# 11                                         63611
# 12                                        759450
# 13                                        312848
#
#    Same state of residence 1 year ago (moe)  \
# 8                                    167671
# 10                                    23356
# 11                                     6501
# 12                                    24263
# 13                                    15129
#
#     Different state of residence 1 year ago (estimate)  \
# 8                                           7859837.0
# 10                                           115641.0
# 11                                            31378.0
# 12                                           264948.0
# 13                                            76108.0
#
#    Different state of residence 1 year ago (moe)  new_people_adj
# 8                                          75123        0.023929
# 10                                         10300        0.023175
# 11                                          3888        0.043343
# 12                                         14419        0.036784
# 13                                          8024        0.025452

# %%
df.sort_values('new_people_adj', ascending=False)

df = df.sort_values('new_people_adj', ascending=False)

# %% [markdown]
# Adjust new_people_adj to be a better formatted percentage

# %%
df['new_people_adj'] = df['new_people_adj'] * 100

# %%
df_comparisan_stateinmigration = pd.DataFrame()
df_comparisan_stateinmigration = df[['state', 'new_people_adj']].head(10)
df_comparisan_stateinmigration
# Out:
#                     state  new_people_adj
# 19  District of Columbia         8.735814
# 24                  Idaho        5.127788
# 23                 Hawaii        5.021812
# 68                Vermont        4.962348
# 55           North Dakota        4.949270
# 74                Wyoming        4.757130
# 16               Colorado        4.342604
# 11                 Alaska        4.334283
# 18               Delaware        4.277906
# 48                 Nevada        4.262849

# %% [markdown]
# export

# %%
df_comparisan_stateinmigration.to_csv('df_comparisan_stateinmigration.csv')
