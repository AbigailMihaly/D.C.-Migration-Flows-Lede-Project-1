# %% [markdown]
# Making charts for this DC inmigration after election years project

# %%
import pandas as pd
import json
import requests
import numpy as np
from datetime import date, datetime
import os
from dotenv import load_dotenv

# %% [markdown]
# https://developer.datawrapper.de/docs/chart-types for each chart type

# %%
access_token=os.getenv("DATAWRAPPER_TOKEN")

headers = {
    "authorization": f"Bearer {access_token}",
    "Accept": "*/*",
    "Content-Type": "application/json"
}

csv_headers = {
    "authorization": f"Bearer {access_token}",
    "Content-Type": "text/csv"
}

datawrapper_chart_url = "https://api.datawrapper.de/v3/charts"
